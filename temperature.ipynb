# %% [markdown]
# <img src="https://bit.ly/2VnXWr2" width="100" align="left">

# %% [markdown]
# # Temperature Sensor
#
# There is a temperature sensor in the processor of your company's server. The company wants to analyze the data provided by the sensor to decide if they should change the cooling system for a better one. As changing the cooling system is expensive and you are an excellent data analyst, you can't make a decision without basis.
#
# ## Tools
# You don't necessarily need to use all the tools. Maybe you opt to use some of them or completely different ones, they are given to help you shape the exercise. Programming exercises can be solved in many different ways.
# 1. Data structures: **lists**
# 2. Loops: **list comprehension**
# 3. Functions: **min, max, print, len**
# 4. Conditional statements: **if-elif-else**
#
# ## Tasks
# The temperatures measured throughout the 24 hours of a day are:

# %%
temperatures_C = [33, 66, 65, 0, 59, 60, 62, 64, 70, 76, 80, 81, 80, 83, 90, 79, 61, 53, 50, 49, 53, 48, 45, 39]

# %% [markdown]
# The first element of the list is the temperature at 12am, the second element is the temperature at 1am, and so on.
#
# The company has decided that if one of the following events occurs, then the cooling system needs to be replaced for a new one to avoid damaging the processor.
# * More than 4 temperatures are greater than or equal to 70ºC.
# * Any temperature is above 80ºC.
# * The average temperature exceeds 65ºC.
#
# Follow the steps so that you can make the decision.
#
# #### 1. Find the minimum temperature of the day and store it in a variable.

# %%
mintemp=min(temperatures_C)

# %% [markdown]
# #### 2. Find the maximum temperature of the day and store it in a variable.

# %%
maxtemp=max(temperatures_C)

# %% [markdown]
# #### 3. Create a list with the temperatures that are greater than or equal to 70ºC. Store it in a variable.

# %%
temperatures_70=[]
for c in temperatures_C:
    if c >= 70:
        temperatures_70.append(c)
print(temperatures_70)
# Out:
# [70, 76, 80, 81, 80, 83, 90, 79]

# %% [markdown]
# #### 4. Find the average temperature of the day and store it in a variable.

# %%
aver_temp=sum(temperatures_C)/len(temperatures_C)

# %% [markdown]
# #### 5. Imagine that there was a sensor failure at 3am and the data for that specific hour was not recorded. How would you estimate the missing value? Replace the current value of the list at 3am for an estimation.

# %%
estimated= int((temperatures_C[2]+temperatures_C[4])/2)
temperatures_C[3] = estimated
print(temperatures_C)
# Out:
# [33, 66, 65, 62, 59, 60, 62, 64, 70, 76, 80, 81, 80, 83, 90, 79, 61, 53, 50, 49, 53, 48, 45, 39]

# %% [markdown]
# #### 6. Bonus: the maintenance staff is from the United States and does not understand the international metric system. Help them by converting the temperatures from Celsius to Fahrenheit.
# To know more about temperature conversion check this [link](https://en.wikipedia.org/wiki/Conversion_of_units_of_temperature).
#
# **Formula**:
#
# $F = 1.8 * C + 32$

# %%
temperatures_F=[]
def Fahrenheit(list):
    for c in list:
        f=1.8*c+32
        temperatures_F.append(round(f,2))

Fahrenheit(temperatures_C)
print(temperatures_F)
# Out:
# [91.4, 150.8, 149.0, 143.6, 138.2, 140.0, 143.6, 147.2, 158.0, 168.8, 176.0, 177.8, 176.0, 181.4, 194.0, 174.2, 141.8, 127.4, 122.0, 120.2, 127.4, 118.4, 113.0, 102.2]

# %% [markdown]
# #### 7. Make a decision!
# Now it's time to make a decision taking into account what you have seen until now.
#
# Remember that if one of the following events occurs, then the cooling system needs to be replaced for a new one to avoid damaging the processor.
# * More than 4 temperatures are greater than or equal to 70ºC.
# * Any temperature is above 80ºC.
# * The average temperature exceeds 65ºC.
#
# #### To make your decision, check if any of the three conditions above is met. You might need to use some of the variables you created in steps 1 to 6. Print a message to show if the cooling system needs to be changed or not.

# %%
for c in temperatures_C:
    if len(temperatures_70)>= 4 or c > 80 or aver_temp>65:
        result=0
    else:
        result=1

if result==0:
    print("the cooling system needs to be changed")
else: 
    print ("the cooling system doesn't needs to be changed")
# Out:
# the cooling system needs to be changed

# %% [markdown]
# ## Bonus
#
# The company has decided that the decision you made is not valid. They want you to analyze the data again but this time, the conditions that need to be met in order to change the cooling system are different.
#
# This time, if one of the following events occurs, then the cooling system needs to be replaced:
# * The temperature is greater than 70ºC during more than 4 consecutive hours.
# * Any temperature is above 80ºC.
# * The average temperature exceeds 65ºC.
#
# Follow the steps so that you can make the decision.
#
# #### 1. Create a list with the hours where the temperature is greater than 70ºC. Store it in a variable.

# %%
Hours_70=[]
for c in temperatures_C:
    if c >=70:
        Hours_70.append(temperatures_C.index(c))
print(Hours_70)
# Out:
# [8, 9, 10, 11, 10, 13, 14, 15]

# %% [markdown]
# #### 2. Check if the list you created in step 1 has more than 4 consecutive hours.

# %%
consecutive=0

for c in Hours_70:
    if (c+1)-(c)==1:
        consecutive+=1
    else:
        consecutive=0

print("We find",consecutive,"hours in the list")

if consecutive>4:
    print("Yes, the list has more than 4 consecutive hours")
# Out:
# We find 8 hours in the list
# Yes, the list has more than 4 consecutive hours

# %% [markdown]
# #### 3. Make the decision!
# To make your decision, check if any of the three conditions is met. Print a message to show if the cooling system needs to be changed or not.

# %%
for c in temperatures_C:
    if consecutive> 4 or c > 80 or aver_temp>65:
        result=0
    else:
        result=1

if result==0:
    print("the cooling system needs to be changed")
else: 
    print ("the cooling system doesn't needs to be changed")
# Out:
# the cooling system needs to be changed

# %% [markdown]
# #### 4. Find the average value of the temperature lists (ºC and ºF). What is the relation between both average values?

# %%
aver_temp_C=round(sum(temperatures_C)/len(temperatures_C),2)
aver_temp_F=round(sum(temperatures_F)/len(temperatures_F),2)

relation=round((1.8*aver_temp_C+ 32),1)

print("The average temperature in ºF is:",aver_temp_F)
print("The average temperature in ºC is:",aver_temp_C)

print("The relation between the average temperatures in ºC and in ºF is exactly the one given to transform the ºC in ºF--> 𝐹=1.8∗𝐶+32,and so we can see that is the same value if we calculate the ecuation again:",relation)

#𝐹=1.8∗𝐶+32
# Out:
# The average temperature in ºF is: 145.1
# The average temperature in ºC is: 62.83
# The relation between the average temperatures in ºC and in ºF is exactly the one given to transform the ºC in ºF--> 𝐹=1.8∗𝐶+32,and so we can see that is the same value if we calculate the ecuation again: 145.1

# %% [markdown]
# #### 5. Find the standard deviation of the temperature lists (ºC and ºF). What is the relation between both standard deviations?

# %%
from math import sqrt
#For Temperature ºC
substractC=[]
squaredC = []
    
for i in temperatures_C:
    operation = i - aver_temp_C
    substractC.append(operation)        
for i in substractC:
    operation_2= i**2
    squaredC.append(operation_2)
  
varC= sum(squaredC)/len(temperatures_C)
deviationC = round(sqrt(varC),2)

print ("The st deviation of the ºC Temperature is",deviationC)

#For Temperature ºF
substractF=[]
squaredF = []
    
for i in temperatures_F:
    operation = i - aver_temp_F
    substractF.append(operation)        
for i in substractF:
    operation_2= i**2
    squaredF.append(operation_2)
  
varF= sum(squaredF)/len(temperatures_F)
deviationF = round(sqrt(varF),2)

print ("The st deviation of the ºC Temperature is",deviationF)

relation=round(deviationC*1.8,3)
print("If the same constant is added to all the values of the variable, the standard deviation does not change and if all the values of the variable are multiplied by the same constant(in this case 1.8), the standard deviation is multiplied by the absolute value of that constant. As we can see in this example, both rules are verified, as the result of multiplying the constant (1.8) and the Celsius St.Deviation is the same value:",relation)
# Out:
# The st deviation of the ºC Temperature is 14.63
# The st deviation of the ºC Temperature is 26.34
# If the same constant is added to all the values of the variable, the standard deviation does not change and if all the values of the variable are multiplied by the same constant(in this case 1.8), the standard deviation is multiplied by the absolute value of that constant. As we can see in this example, both rules are verified, as the result of multiplying the constant (1.8) and the Celsius St.Deviation is the same value: 26.334
